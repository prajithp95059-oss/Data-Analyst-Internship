# %% [markdown]
# <h1  style="color:darkblue;"><div style="text-align: center;"><strong><u>IMDB MOVIE DETAILS</u></strong></div></h1>
# *IMDb (Internet Movie Database) is a comprehensive online resource for information about movies, TV shows, actors, directors, and production crews. It offers ratings, reviews, cast details, trivia, and box office data for millions of titles worldwide. Founded in 1990, IMDb is widely used by fans and professionals to explore entertainment content and industry insights.*

# %% [markdown]
# <h1 style="text-align: center;color:darkblue;"><u>IMPORTING</u></h1>
# <div style="text-align: center;">
#   <strong  style="color:darkblue;">Importing four powerful Python libraries commonly used in data analysis and visualization.</strong>
# </div>
#
#  <u><strong  style="color:purple;">import numpy as np</strong></u>
#
# - *NumPy is short for Numerical Python.*
# - *It provides fast, efficient operations on arrays, matrices, and numerical data.*
#
#  <u><u><strong  style="color:purple;">import pandas as pd</strong></u>
#
# - *Pandas is used for handling structured data like tables.*
# - *It introduces DataFrame and Series objects for easy data manipulation.*
#
#  <u><strong  style="color:purple;">import matplotlib.pyplot as plt</strong></u>
#
# - *Matplotlib is a plotting library.*
# - *pyplot is its module for creating basic visualizations like line plots, bar charts, and scatter plots.*
#
#  <u><strong  style="color:purple;">import seaborn as sns</strong></u>
#
# - *Seaborn builds on Matplotlib and adds statistical plotting with better aesthetics.*
# - *It’s great for visualizing distributions, correlations, and categorical data.*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Downloads/imdb_data (1).csv")
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.shape
# Out:
# (3000, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
df.duplicated().value_counts()
# Out:
# False    3000
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %%
df.drop(columns="belongs_to_collection",axis=1,inplace=True)
df.drop(columns="homepage",axis=1,inplace=True)
df
# Out:
#         id    budget                                             genres  \
# 0        1  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1        2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2        3   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3        4   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4        5         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...    ...       ...                                                ...
# 2995  2996         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  2997         0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  2998  65000000  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  2999  42000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  3000  35000000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#         imdb_id original_language                            original_title  \
# ...

# %% [markdown]
# <h2  style="color:darkblue;">🧾Observation: Column Removal</h2>
#
# - Dropped `belongs_to_collection` and `homepage` columns using `df.drop()` with `inplace=True`.
# - These columns were likely irrelevant for analysis or contained too many missing values.
# - Removing them helps simplify the dataset and focus on more meaningful features like `title`, `genre`, `budget`, and `rating`.
# - This step is part of data cleaning to prepare for effective visualization and modeling.

# %%
df.columns
# Out:
# Index(['id', 'budget', 'genres', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'Keywords',
#        'cast', 'crew', 'revenue'],
#       dtype='object')

# %% [markdown]
# ### Handling missing values

# %%
df["genres"].fillna(value="genres not provided",inplace=True)

# %%
df["overview"].fillna(value="overview not provided",inplace=True)

# %%
df["poster_path"].fillna(value="poster path not provided",inplace=True)

# %%
df["production_companies"].fillna(value="details not provided",inplace=True)

# %%
df["production_countries"].fillna(value="no details",inplace=True)

# %%
df["runtime"].fillna(value="Not provided",inplace=True)

# %%
df["spoken_languages"].fillna(value="language unknown",inplace=True)

# %%
df["tagline"].fillna(value="not provided",inplace=True)

# %%
df["Keywords"].fillna(value="not available",inplace=True)

# %%
df["cast"].fillna(value="cast detail not available",inplace=True)

# %%
df["crew"].fillna(value="crew detail not available",inplace=True)

# %% [markdown]
# <h2  style="color:darkblue;">🧾Observation :</h2>
#
# -  The details are provided to fill the columns.
# -  we fill the number of columns with `fillna`.
# -  Without filling the data we cannot able to move on to the next step.

# %%
df.isnull().sum()
# Out:
# id                      0
# budget                  0
# genres                  0
# imdb_id                 0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# poster_path             0
# production_companies    0
# production_countries    0
# release_date            0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# Keywords                0
# cast                    0
# crew                    0
# revenue                 0
# genres_list             0
# dtype: int64

# %% [markdown]
# <h2  style="color:darkblue;">🧾Observation: Final Null Check</h2>
#
# - Used `df.isnull().sum()` to verify that all missing values have been handled.
# - This confirms that previous cleaning steps (using `fillna()` and `drop()`) were successful.
# - A result of all zeros means the dataset is now complete and ready for analysis or visualization.
# - This step ensures data integrity before moving on to feature engineering or modeling.

# %%
top_lang=df["original_language"].value_counts().head(3)
top_lang
# Out:
# original_language
# en    2575
# fr      78
# ru      47
# Name: count, dtype: int64

# %%
color=["pink","skyblue","yellow"]
plt.pie(top_lang,labels=top_lang.index,colors=color,autopct="%1.1f%%")
plt.show()

# %%
from collections import Counter
import ast
# Function to extract genre names from the JSON-like strings, handling potential errors
def extract_genre_names(genres_str):
    try:
        genres = ast.literal_eval(genres_str)
        return [genre['name'] for genre in genres]
    except (SyntaxError, ValueError):
        return ['Unknown']  # Replace with a default value or handle error as needed

# Apply the function to the 'genres' column
df['genres_list'] =df['genres'].apply(extract_genre_names)

# Flatten the list of genres and count occurrences
all_genres = [genre for sublist in df['genres_list'] for genre in sublist]
genre_counts = Counter(all_genres)

# Convert the counter to a DataFrame for easy plotting
genre_counts_df = pd.DataFrame(genre_counts.items(), columns=['Genre', 'Count'])

# %% [markdown]
# <h2 style="color:darkblue;">🧾Observation: Genre Distribution</h2>
#
# - Extracted genre names from the `genres` column using `ast.literal_eval()` and stored them in a new column `genres_list`.
# - Flattened the nested genre lists and counted occurrences using `collections.Counter`.
# - Converted the genre frequency data into a DataFrame `genre_counts_df` for easy plotting.
# - This process reveals the most common genres in the dataset, enabling genre-based analysis and visualization.
# - Helps identify dominant themes (e.g., Action, Drama, Comedy) and supports filtering or trend exploration.

# %%
print("Genre counts:")
for genre,count in genre_counts.items():
    print(f"{genre}:{count}")
# Out:
# Genre counts:
# Comedy:1028
# Drama:1531
# Family:260
# Romance:571
# Thriller:789
# Action:741
# Animation:141
# Adventure:439
# Horror:301
# Documentary:87
# Music:100
# Crime:469
# Science Fiction:290
# Mystery:225
# Foreign:31
# Fantasy:232
# War:100
# Western:43
# History:132
# Unknown:7
# TV Movie:1

# %% [markdown]
# <h2 style="color:darkblue;">🧾Observation: Genre Frequency Summary</h2>
#
# - Printed the frequency of each genre using a loop over `genre_counts`.
# - This gives a clear view of how many movies fall under each genre.
# - Common genres like **Drama**, **Comedy**, and **Action** typically appear at the top.
# - Less frequent genres (e.g., **Western**, **War**, **Music**) help identify niche categories in the dataset.
# - This breakdown supports genre-based filtering, trend analysis, and targeted visualizations.

# %%
a=genre_counts_df.plot(kind="bar",x="Genre",y="Count",color="green")
plt.xlabel("genre")
plt.ylabel("counts")
plt.title("Genre count")
for index,value in enumerate(genre_counts_df['Count'] ):
    plt.text(index,value,str(value),ha="center",va="bottom",fontsize=10,fontweight="bold")
plt.show()

# %% [markdown]
# <h2 style="color:darkblue;">🧾Observation: Genre Count Distribution</h2>
#
# - The bar chart displays the frequency of each genre in the dataset.
# - **Drama**, **Comedy**, and **Action** are among the most represented genres, indicating their dominance in movie production.
# - Less frequent genres like **War**, **Western**, and **Music** appear with smaller bars, highlighting niche categories.
# - Annotated counts on each bar improve readability and help quickly compare genre popularity.
# - This visualization supports genre-based filtering, trend analysis, and helps prioritize genres for deeper exploration.

# %%
df.groupby("original_title")["popularity"].sum().sort_values(ascending=False)
# Out:
# original_title
# Wonder Woman                               294.337037
# Beauty and the Beast                       287.253654
# Baby Driver                                228.032744
# Deadpool                                   187.860492
# Guardians of the Galaxy Vol. 2             185.330992
#                                               ...
# Live Nude Girls Unite!                       0.001272
# Campus Man                                   0.000844
# And You Thought Your Parents Were Weird      0.000578
# The Slugger's Wife                           0.000308
# Big Time                                     0.000001
# Name: popularity, Length: 2975, dtype: float64

# %%
top10=df.groupby("original_title")["popularity"].sum().sort_values(ascending=False).head(10)
top10
# Out:
# original_title
# Wonder Woman                      294.337037
# Beauty and the Beast              287.253654
# Baby Driver                       228.032744
# Deadpool                          187.860492
# Guardians of the Galaxy Vol. 2    185.330992
# Gone Girl                         154.801009
# War for the Planet of the Apes    146.161786
# The Dark Knight                   123.167259
# The Avengers                       89.887648
# The Circle                         88.439243
# Name: popularity, dtype: float64

# %%
plt.plot(top10,color="red",marker="*",linestyle="--")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <h2 style="color:darkblue;">🧾Observation: Top 10 Movie Popularity (Line Chart)</h2>
#
# - The line chart visualizes the popularity scores of the top 10 movies.
# - Each point is marked and connected with dashed lines to show the trend clearly.
# - The x-axis labels are rotated for better readability of movie titles.
# - The chart reveals a steep drop after the top few titles, indicating that a small number of movies dominate in popularity.
# - This visualization helps highlight blockbuster films and compare their relative popularity.

# %%
top_7=df.sort_values(by="budget",ascending=False).head(7)
top_7
# Out:
#         id     budget                                             genres  \
# 2135  2136  380000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 2209  2210  300000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2770  2771  280000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1425  1426  270000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 1630  1631  260000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 1270  1271  260000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 666    667  250000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#         imdb_id original_language  \
# 2135  tt1298650                en
# 2209  tt0449088                en
# 2770  tt2395427                en
# 1425  tt0348150                en
# 1630  tt3371366                en
# 1270  tt0401729                en
# 666   tt1170358                en
#
#                                    original_title  \
# ...

# %%
top_7[["original_title", "budget"]]
# Out:
#                                    original_title     budget
# 2135  Pirates of the Caribbean: On Stranger Tides  380000000
# 2209     Pirates of the Caribbean: At World's End  300000000
# 2770                      Avengers: Age of Ultron  280000000
# 1425                             Superman Returns  270000000
# 1630                Transformers: The Last Knight  260000000
# 1270                                  John Carter  260000000
# 666           The Hobbit: The Desolation of Smaug  250000000

# %%
plt.figure(figsize=(18, 10))
b = top_7.plot(kind="barh", x="original_title", y="budget", color="purple", legend=False)
plt.xlabel("Budget (in millions USD)")
plt.ylabel("Film")
plt.title("Top 7 Budget Films")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
for index, value in enumerate(top_7["budget"]):
    plt.text(value + 5, index, str(value), va="center", ha="left", fontsize=10, fontweight="bold")
plt.show()

# %% [markdown]
# <h2 style="color:darkblue;">🧾Observation: Top 7 Budget Films (Horizontal Bar Chart)</h2>
#
# - The horizontal bar chart displays the 7 highest-budget movies in the dataset.
# - Each bar is labeled with its exact budget value for clarity.
# - The chart shows a steep budget range, with one or two films having significantly higher investments than the rest.
# - This visualization highlights the financial scale of blockbuster productions and helps compare spending across top titles.

# %% [markdown]
# <h2 style="color:darkblue;">Observations Summary</h2>
#
# - **Top Languages**: English is overwhelmingly dominant, with other languages contributing minimally. This reflects a strong bias toward English-language films in the dataset.
# - **Genre Distribution**: Drama, Comedy, and Action are the most frequent genres, while niche genres like War and Western appear less often.
# - **Genre Visualization**: The bar chart clearly highlights genre popularity, with annotated counts improving readability and comparison.
# - **Top 10 Popular Movies**: A few titles stand out with exceptionally high cumulative popularity, suggesting blockbuster status or multiple entries.
# - **Popularity Chart**: The line plot shows a steep drop after the top few titles, indicating that popularity is concentrated among select movies.
# - **Top Budget Films**: The highest-budget movies reflect large-scale productions, likely involving high-end effects, star casts, and global releases.
# - **Budget Chart**: The horizontal bar chart reveals a wide budget range, with one or two films far exceeding others in financial investment.

# %% [markdown]
# <h2 style="color:darkblue;">🧠Final Conclusion (Key Points)</h2>
#
# - The dataset is **dominated by English-language films**, reflecting global production and distribution trends.
# - **Mainstream genres** like Drama, Comedy, and Action are the most frequent, indicating audience preference and industry focus.'
# - **Popularity is concentrated** among a few blockbuster titles, with steep drop-offs after the top-ranked movies.
# - **High-budget films** show significant financial investment, often linked to large-scale productions and global releases.
# - Visualizations (pie, bar, line charts) effectively highlight **distribution patterns**, making trends easy to interpret.
# - These insights provide a strong foundation for further analysis into **genre success**, **language representation**, and **financial strategies** in film production.
